# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer

# %%
X = pd.read_csv("data/theonion_processed.csv")
X.head()
# Out:
#    Unnamed: 0                                              heads  \
# 0           0  inclement weather prevents liar from getting t...
# 1           1  mother comes pretty close to using word stream...
# 2           2  richard bransons globalwarming donation nearly...
# 3           3  shadow government getting too large to meet in...
# 4           4  ford develops new suv that runs purely on gaso...
#
#                                                descs
# 0  PROVIDENCE RI—In spite of his best efforts to ...
# 1  PATERSON NJ—Family sources told reporters Tues...
# 2  LONDON—Analysts are predicting that the 3 bill...
# 3  COLUMBUS OH—With its membership swelling in re...
# 4  DEARBORN MI—The Ford Motor Company announced W...

# %%
tokens = X['descs']

# %%
cv = CountVectorizer(max_df=0.85)
X_cv = cv.fit_transform(tokens)

# %%
print(list(cv.vocabulary_.keys())[:10])
# Out:
# ['providence', 'ri', 'spite', 'his', 'best', 'efforts', 'brave', 'ongoing', 'winter', 'storm']

# %%
tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
tfidf_transformer.fit(X_cv)
# Out:
# TfidfTransformer()

# %%
cv.get_feature_names()
# Out:
# ['00',
#  '00000000001',
#  '0000000001ounce',
#  '0000001',
#  '0000004',
#  '000001',
#  '000002',
#  '00003',
#  '00005',
#  '000082567kln00067x',
#  '001',
#  '00100000',
#  '00100111',
#  '00101100',
#  '00101101',
#  '00101110',
#  '002',
#  '003',
#  '005',
#  '007',
#  '01',
#  '0100',
#  '01000001',
#  '01000100',
#  '01001001',
#  '01100001',
#  '01100011',
#  '01100100',
#  '01100101',
#  '01100110',
#  '01100111',
#  '01101000',
#  '01101001',
#  '01101011',
#  '01101100',
#  '01101101',
#  '01101110',
#  '01101111',
#  '01110000',
#  '01110010',
#  '01110011',
#  '01110100',
#  '01110101',
#  '01110110',
#  '01110111',
#  '01111001',
#  '0115',
#  '014',
#  '02',
#  '020',
#  '025',
#  '02milligram',
#  '03',
#  '03130',
#  '04',
#  '05',
#  '06',
#  '0600',
#  '07',
#  '0700',
#  '072',
#  '074',
#  '075off',
#  '07magnitude',
#  '08',
#  '08ounce',
#  '08second',
#  '09',
#  '095400',
#  '10',
#  '100',
#  '1000',
#  '10000',
#  '100000',
#  '1000000',
#  '100000aday',
#  '10000degree',
#  '10000degreefahrenheit',
#  '10000foot',
#  '10000milelong',
#  '1000foottall',
#  '1000gallon',
#  '1000pound',
#  '1000pump',
#  '1000th',
#  '1000watt',
#  '1000year',
#  '1001',
#  '100120',
#  '1003inch',
#  '10045',
#  '1005',
#  '100aportion',
#  '100baht',
#  '100baset',
#  '100day',
#  '100degree',
#  '100hour',
#  '100meter',
#  '100milligram',
#  '100percent',
#  '100s',
#  '100seat',
#  '100th',
#  '100yard',
#  '100yearlong',
#  '101',
#  '1010220',
#  '1012',
#  '1015',
#  '101670',
#  '1019',
#  '101st',
#  '1020',
#  '1022',
#  '103',
#  '1030',
#  '1032',
#  '103mile',
#  '104',
#  '1040',
#  '1040s',
#  '1045',
#  '10471054',
#  '104yearold',
#  '1050perhour',
#  '1059',
#  '106',
#  '107',
#  '1076page',
#  '108',
#  '1080',
#  '1080degree',
#  '1085',
#  '108s',
#  '108th',
#  '108yearold',
#  '1099',
#  '1099bs',
#  '1099int',
#  '1099misc',
#  '1099s',
#  '109c',
#  '10blade',
#  '10by10',
#  '10by10foot',
#  '10by12foot',
#  '10by14inch',
#  '10car',
#  '10cc',
#  '10day',
#  '10dayold',
#  '10episode',
#  '10figure',
#  '10foot',
#  '10foottall',
#  '10footwide',
#  '10hour',
#  '10inch',
#  '10k',
#  '10letter',
#  '10man',
#  '10mealper',
#  '10mile',
#  '10milligram',
#  '10minute',
#  '10minutelong',
#  '10month',
#  '10monthold',
#  '10nation',
#  '10ounce',
#  '10pack',
#  '10page',
#  '10part',
#  '10point',
#  '10pound',
#  '10room',
#  '10second',
#  '10some',
#  '10spots',
#  '10step',
#  '10store',
#  '10storytall',
#  '10th',
#  '10thgrade',
#  '10thgrader',
#  '10thgraders',
#  '10time',
#  '10week',
#  '10year',
#  '10yearlong',
#  '10yearold',
#  '10yearolds',
#  '11',
#  '110',
#  '1100',
#  '11000',
#  '110000',
#  '1100word',
#  '1102',
#  '1105',
#  '1108',
#  '110degree',
#  '110perhour',
#  '110th',
#  '111',
#  '1113',
#  '1114',
#  '1115',
#  '1117thgeneration',
#  '111th',
#  '111year',
#  '112',
#  '1120',
#  '11200cubicmile',
#  '112th',
#  '112year',
#  '113',
#  '1130',
#  '11301030c',
#  '1135',
#  '1137',
#  '113th',
#  '114',
#  '1140',
#  '114000',
#  '1142',
#  '1145',
#  '11454',
#  '114786',
#  '115',
#  '1150',
#  '1153',
#  '1159',
#  '115by7inch',
#  '115page',
#  '115th',
#  '116',
#  '116thpage',
#  '116yearold',
#  '117',
#  '1170',
#  '11717',
#  '11717ians',
#  '1173',
#  '1175',
#  '1179mile',
#  '117strong',
#  '117yearolds',
#  '118',
#  '11816',
#  '1187foot',
#  '119',
#  '1199',
#  '119minute',
#  '11inch',
#  '11mile',
#  '11minute',
#  '11percentalcohol',
#  '11point',
#  '11story',
#  '11th',
#  '11thgrade',
#  '11thgraders',
#  '11thhour',
#  '11to12yearolds',
#  '11to13yearold',
#  '11ton',
#  '11year',
#  '11yearold',
#  '11yearolds',
#  '11yearsold',
#  '12',
#  '120',
#  '1200',
#  '12000',
#  '120000',
#  '12000000th',
#  '12000word',
#  '1200page',
#  '1200pound',
#  '1200word',
#  '120page',
#  '120squarefoot',
#  '120word',
#  '121',
#  '1212',
#  '1213',
#  '1215',
#  '122',
#  '12204',
#  '12285',
#  '123',
#  '1230',
#  '1232',
#  '123456',
#  '123yearold',
#  '124',
#  '1245',
#  '125',
#  '125acre',
#  '125cubicmile',
#  '125milewide',
#  '125person',
#  '126',
#  '12600',
#  '127',
#  '1273',
#  '1279',
#  '127minute',
#  '128',
#  '128000',
#  '128bit',
#  '1299',
#  '12999',
#  '12anhour',
#  '12c',
#  '12centimeterlong',
#  '12day',
#  '12dayold',
#  '12disc',
#  '12dvd',
#  '12episode',
#  '12foot',
#  '12footlong',
#  '12gallon',
#  '12handsbreadth',
#  '12hour',
#  '12inch',
#  '12inchtall',
#  '12inchthick',
#  '12inning',
#  '12item',
#  '12lane',
#  '12man',
#  '12member',
#  '12minute',
#  '12minutelong',
#  '12month',
#  '12monthold',
#  '12nation',
#  '12ounce',
#  '12pack',
#  '12packs',
#  '12part',
#  '12person',
#  '12point',
#  '12quart',
#  '12question',
#  '12ride',
#  '12s',
#  '12second',
#  '12session',
#  '12story',
#  '12th',
#  '12thcentury',
#  '12thfloor',
#  '12thgrade',
#  '12thgrader',
#  '12tooct',
#  '12week',
#  '12word',
#  '12year',
#  '12yearold',
#  '12yearolds',
#  '13',
#  '130',
#  '1300',
#  '13000',
#  '130000',
#  '13000yearold',
#  '130yearlong',
#  '130yearold',
#  '131',
#  '1311',
#  '131106',
#  '1313',
#  '1329',
#  '133',
#  '1339',
#  '134',
#  '13434',
#  '1347',
#  '134year',
#  '134yearold',
#  '135',
#  '135000',
#  '135285',
#  '13546873',
#  '135gallon',
#  '136',
#  '13600',
#  '1360thpart',
#  '13680hour',
#  '137',
#  '1375',
#  '138',
#  '1381',
#  '13846',
#  '1386',
#  '138yearold',
#  '139',
#  '139000',
#  '1395',
#  '13acre',
#  '13billion',
#  '13episode',
#  '13foottall',
#  '13hour',
#  '13inch',
#  '13mile',
#  '13month',
#  '13pitch',
#  '13th',
#  '13time',
#  '13to18yearolds',
#  '13year',
#  '13yearold',
#  '13yearolds',
#  '14',
#  '140',
#  '1400',
#  '14000',
#  '140000',
#  '140character',
#  '140mph',
#  '140squaremile',
#  '1418',
#  '142',
#  '142cubicfoot',
#  '142person',
#  '143',
#  '144',
#  '1446',
#  '145',
#  '146',
#  '14600',
#  '146th',
#  '147',
#  '1472',
#  '148',
#  '1485',
#  '14945',
#  '1495',
#  '1499',
#  '149th',
#  '14day',
#  '14figure',
#  '14foot',
#  '14hand',
#  '14horsepower',
#  '14hour',
#  '14hourold',
#  '14inch',
#  '14karat',
#  '14lb',
#  '14mile',
#  '14mileperhour',
#  '14month',
#  '14monthold',
#  '14movie',
#  '14ounce',
#  '14point',
#  '14s',
#  '14th',
#  '14thcentury',
#  '14vote',
#  '14year',
#  '14yearold',
#  '14yearolds',
#  '15',
#  '150',
#  '1500',
#  '15000',
#  '150000',
#  '150200pound',
#  '150degree',
#  '150foot',
#  '150minute',
#  '150pound',
#  '150ton',
#  '150word',
#  '150yearlong',
#  '151',
#  '1511',
#  '1518yearolds',
#  '1520',
#  '1520minute',
#  '1535',
#  '153word',
#  '153yearold',
#  '154',
#  '1542',
#  '1544s',
#  '1549',
#  '155',
#  '1556',
#  '1559',
#  '155th',
#  '155yearold',
#  '156',
#  '1560',
#  '156pound',
#  '157',
#  '1578',
#  '157foottall',
#  '158',
#  '1587pound',
#  '1588',
#  '158page',
#  '159',
#  '1590',
#  '15billionyearold',
#  '15by18foot',
#  '15by20foot',
#  '15candle',
#  '15day',
#  '15foot',
#  '15ghz',
#  '15houraweek',
#  '15mile',
#  '15million',
#  '15milliongallon',
#  '15millionyearold',
#  '15minute',
#  '15person',
#  '15piece',
#  '15pound',
#  '15second',
#  '15th',
#  '15thcentury',
#  '15thperiod',
#  '15to1',
#  '15week',
#  '15word',
#  '15year',
#  '15yearold',
#  '15yearolds',
#  '16',
#  '160',
#  '1600',
#  '16000',
#  '160000',
#  '1600plus',
#  '1600s',
#  '1600squaremile',
#  '1605810913',
#  '160second',
#  '160word',
#  '160yearold',
#  '161',
#  '1610',
#  '162',
#  '1620',
#  '1623',
#  '1626',
#  '1627',
#  '162yearold',
#  '1630',
#  '163yearold',
#  '1643rd',
#  '164word',
#  '165',
#  '1660',
#  '16743',
#  '16765hour',
#  '16780',
#  '1679',
#  '168',
#  '1680',
#  '168000',
#  '1690',
#  '1696',
#  '1699',
#  '16bit',
#  '16daylong',
#  '16foot',
#  '16footwide',
#  '16hour',
#  '16inch',
#  '16monthold',
#  '16ounce',
#  '16page',
#  '16piece',
#  '16story',
#  '16th',
#  '16thcentury',
#  '16thdegree',
#  '16to1',
#  '16word',
#  '16year',
#  '16yearold',
#  '16yearolds',
#  '17',
#  '170',
#  '17000',
#  '1700s',
#  '170foot',
#  '170mileperhour',
#  '170plus',
#  '171',
#  '1714',
#  '172',
#  '1723',
#  '174',
#  '1743',
#  '1744mile',
#  '17476',
#  '175',
#  '1750',
#  '17500',
#  '175liter',
#  '175th',
#  '175yearold',
#  '176',
#  '176935page',
#  '177',
#  '1775',
#  '1779',
#  '178',
#  '178000',
#  '1782',
#  '178230',
#  '1783',
#  '1785',
#  '1789',
#  '179',
#  '1791',
#  '1796',
#  '1799',
#  '17d',
#  '17day',
#  '17hour',
#  '17inch',
#  '17incher',
#  '17minute',
#  '17month',
#  '17monthold',
#  '17page',
#  '17story',
#  '17th',
#  '17thcentury',
#  '17thdegree',
#  '17thhighest',
#  '17thrated',
#  '17year',
#  '17yearold',
#  '17yearolds',
#  '18',
#  '180',
#  '1800',
#  '18000',
#  '180000',
#  '1800callatt',
#  '1800eatshit',
#  '1800notcain',
#  '1800room',
#  '1800s',
#  '1804',
#  '180degree',
#  '180second',
#  '180threadcount',
#  '1813',
#  '1815',
#  '182',
#  '1820',
#  '1820s',
#  '1822',
#  '1823',
#  '1826',
#  '182cubicfoot',
#  '183',
#  '1831',
#  '183530',
#  '1837',
#  '1838',
#  '1839',
#  '184',
#  '1840',
#  '1840s',
#  '1840sera',
#  '1844',
#  '1846',
#  '1849',
#  '184page',
#  '185',
#  '1850',
#  '1850s',
#  '1851',
#  '1855',
#  '1859',
#  '185page',
#  '1860s',
#  '1861',
#  '1865',
#  '1868',
#  '1870s',
#  '1871',
#  '1872',
#  '1873',
#  '1879',
#  '1880',
#  '1881',
#  '1887',
#  '1888',
#  '1889',
#  '188x109',
#  '1890',
#  '1892',
#  '1894',
#  '1897',
#  '1898',
#  '1899',
#  '18anhour',
#  '18balloon',
#  '18by20inch',
#  '18hour',
#  '18inch',
#  '18million',
#  '18minute',
#  '18month',
#  '18monthold',
#  '18ounce',
#  '18pound',
#  '18squarefoot',
#  '18th',
#  '18thcentury',
#  '18time',
#  '18to24yearold',
#  '18to24yearolds',
#  '18to28yearolds',
#  '18to29',
#  '18to29yearold',
#  '18to34yearold',
#  '18to35yearold',
#  '18to36yearold',
#  '18ton',
#  '18volt',
#  '18week',
#  '18wheeler',
#  '18wheelers',
#  '18year',
#  '18yearold',
#  '18yearolds',
#  '19',
#  '190',
#  '1900',
#  '1900d',
#  '1900mile',
#  '1900newbill',
#  '1900pound',
#  '1901',
#  '1903',
#  '1907',
#  '1908',
#  '190pound',
#  '1910',
#  '1911',
#  '1914',
#  '1915',
#  '1919',
#  '1919s',
#  '192',
#  '1920',
#  '192000000',
#  '1920s',
#  '1920sera',
#  '1920x1200',
#  '1923',
#  '1926',
#  '1927',
#  '1928',
#  '1928s',
#  '1929',
#  '192nation',
#  '1930',
#  '1930s',
#  '1930sera',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1935',
#  '1936',
#  '1937',
#  '1939',
#  '193yearold',
#  '1940',
#  '1940s',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1950',
#  '1950s',
#  '1950sera',
#  '1950sthemed',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '196',
#  '1960',
#  '19600',
#  '1960s',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '19641973',
#  '196466',
#  '1965',
#  '1965to1973',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '196950000',
#  '196yearold',
#  '1970',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '19732003',
#  '1974',
#  '19741977',
#  '1974b',
#  '1975',
#  '1976',
#  '1976s',
#  '1977',
#  '1978',
#  '1978s',
#  '1979',
#  '1979s',
#  '197pound',
#  '1980',
#  '1980s',
#  '1980sera',
#  '1981',
#  '1982',
#  '1983',
#  '1983s',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '198994',
#  '199',
#  '1990',
#  '1990s',
#  '1991',
#  '1991s',
#  '1992',
#  '1993',
#  '1994',
#  '1994s',
#  '1995',
#  '1996',
#  '1996s',
#  '1997',
#  '1998',
#  '19989',
#  '1998s',
#  '1999',
#  '19999',
#  '1999era',
#  '1999s',
#  '19character',
#  '19day',
#  '19foot',
#  '19hour',
#  '19minute',
#  '19th',
#  '19thcentury',
#  '19yearold',
#  '19yearolds',
#  '1in2',
#  '1inch',
#  '1megabyte',
#  '1s',
#  '1squareinch',
#  '1st',
#  '1summervacation',
#  '1x1078',
#  '1yearold',
#  '20',
#  '200',
#  '2000',
#  '20000',
#  '200000',
#  '20000000',
#  '2000000volts',
#  '200000squarefoot',
#  '20000candlepower',
#  '20000donors',
#  '20000gallon',
#  '20000s',
#  '20000seat',
#  '2000character',
#  '2000degree',
#  '2000mile',
#  '2000milewide',
#  '2000pound',
#  '2000s',
#  '2000yearold',
#  '2001',
#  '2001s',
#  '2002',
#  '2002s',
#  '2003',
#  '2004',
#  '2005',
#  '20052013',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2009s',
#  '200acre',
#  '200amp',
#  '200aticket',
#  '200count',
#  '200dish',
#  '200mph',
#  '200page',
#  '200person',
#  '200pound',
#  '200room',
#  '200word',
#  '200yearold',
#  '201',
#  '2010',
#  '2010s',
#  '2011',
#  '2011s',
#  '2012',
#  '20122013',
#  '2012s',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '20172018',
#  '2018',
#  '2018s',
#  '2019',
#  '202',
#  '2020',
#  '2020s',
#  '2021',
#  '2022',
#  '2023',
#  '2024',
#  '2025',
#  '2026',
#  '2027',
#  '2028',
#  '2029',
#  '203',
#  '2030',
#  '2032',
#  '2033',
#  '20332036',
#  '2035',
#  '2036',
#  '2036s',
#  '2037',
#  '2038',
#  '204',
#  '2040',
#  '2041',
#  '2042',
#  '2043',
#  '2044',
#  '2045',
#  '2049',
#  '204page',
#  '205',
#  '2050',
#  '2052',
#  '2055',
#  '205768',
#  '206',
#  '2060',
#  '2065',
#  ...]

# %%
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_top_n_from_vector(feature_names, sorted_items, top_n=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    if top_n is not None:
        sorted_items = sorted_items[:top_n]

    score_vals = []
    feature_vals = []

    for idx, score in sorted_items:
        fname = feature_names[idx]
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature,score
    #results = zip(feature_vals,score_vals)
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %%
feature_names = cv.get_feature_names()
keywords = []
for single_tokens in tokens:
    tfidf_vector = tfidf_transformer.transform(cv.transform([single_tokens]))
    
    sorted_items = sort_coo(tfidf_vector.tocoo())

    keywords.append(extract_top_n_from_vector(feature_names,sorted_items,10))

# %%
X['keywords']=keywords
print(X)
# Out:
#        Unnamed: 0                                              heads  \
# 0               0  inclement weather prevents liar from getting t...
# 1               1  mother comes pretty close to using word stream...
# 2               2  richard bransons globalwarming donation nearly...
# 3               3  shadow government getting too large to meet in...
# 4               4  ford develops new suv that runs purely on gaso...
# ...           ...                                                ...
# 10575       10575  polish rapper under fire for use of the word p...
# 10576       10576       jews to celebrate rosh hashasha or something
# 10577       10577  internal affairs investigator disappointed con...
# 10578       10578  mars probe destroyed by orbiting spielberggate...
# 10579       10579                 dad clarifies this not a food stop
#
#                                                    descs  \
# 0      PROVIDENCE RI—In spite of his best efforts to ...
# 1      PATERSON NJ—Family sources told reporters Tues...
# 2      LONDON—Analysts are predicting that the 3 bill...
# 3      COLUMBUS OH—With its membership swelling in re...
# 4      DEARBORN MI—The Ford Motor Company announced W...
# ...                                                  ...
# 10575  DETROIT— MC Krakow a popular Detroitbased rapp...
# 10576  JERUSALEM—Jews the world over are preparing to...
# 10577  MILFORD CT—Milford Police Department Internal ...
# 10578  CAPE CANAVERAL FL—NASA officials have confirme...
# 10579  DENTON TX—Stressing that they were there solel...
#
#                                                 keywords
# 0      {'carlson': 0.25, 'weather': 0.196, 'spotty': ...
# 1      {'burkhart': 0.356, 'she': 0.283, 'close': 0.2...
# 2      {'branson': 0.439, 'virgin': 0.235, 'balloonba...
# 3      {'marriotts': 0.177, 'meeting': 0.176, 'confer...
# 4      {'gasoline': 0.354, 'petrola': 0.296, 'nair': ...
# ...                                                  ...
# 10575  {'polack': 0.378, 'krakow': 0.378, 'mc': 0.342...
# 10576  {'jewish': 0.333, 'hosea': 0.315, 'jews': 0.23...
# 10577  {'ferris': 0.374, 'milford': 0.233, 'puzzle': ...
# 10578  {'spielberg': 0.406, 'gates': 0.345, 'nasa': 0...
# 10579  {'whitcomb': 0.511, 'okayed': 0.178, 'chex': 0...
#
# [10580 rows x 4 columns]

# %%
print("\n=====Words=====")
print(tokens[3])
print("\n===Keywords===")
for k in keywords[3]:
    print(k,keywords[3][k])
# Out:
# =====Words=====
# COLUMBUS OH—With its membership swelling in recent months the mysterious organization that secretly pulls the levers of American power was forced to suspend its weekly meeting Monday having grown too big to fit inside Marriott Conference Room B To successfully carry out our clandestine operations and continue maintaining the ignorance of the masses we will now require the full amenities of Conference Room A said an unidentified man who is believed to have covertly orchestrated the economic collapse of Iceland last year We must postpone the Cataclysmic Event until such time as a more comfortable meeting space is available According to confidential records the hidden regimes enrollment has more than doubled since it gained free access to the Marriotts swimming pool and gym facilities
#
# ===Keywords===
# marriotts 0.177
# meeting 0.176
# conference 0.166
# levers 0.16
# enrollment 0.16
# covertly 0.16
# marriott 0.157
# regimes 0.151
# postpone 0.151
# orchestrated 0.151

# %%
X.to_csv("data/keyworded.csv")
